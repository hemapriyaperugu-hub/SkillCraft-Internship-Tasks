# %% [markdown]
# <a href="https://colab.research.google.com/github/hemapriyaperugu-hub/SkillCraft-Internship-Tasks/blob/main/Task3_SkillCraft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
password=input("Enter a password: ")
strength=0
if len(password)>=8:
  strength+=1
if any(char.isupper() for char in password):
  strength+=1
if any(char.islower() for char in password):
    strength+=1
if any(char.isdigit() for char in password):
    strength+=1
if any(not char.isalnum() for char in password):
  strength+=1
if strength<=2:
  print("Weak password!! Try again")
elif strength<=4:
  print("The password must contain at least one uppercase letter, one lowercase letter,one digit and one special character")
else:
  print("Strong password")
# Out:
# Enter a password: Hemapriya
# The password must contain at least one uppercase letter, one lowercase letter, one digit, and one special character.
